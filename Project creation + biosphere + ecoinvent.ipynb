# %% [markdown]
# ## Project creation + Biosphere + Ecoinvent
#
# This file contains the instructions to create a Brightway2 project and load the Ecoinvent and Biosphere databases on it.
# Additionally the instructions to load the Foreground inventory for Hydrogen production and the RTE FE2050 scenarios modelled using the current neighbouring imports market share are also available.
#
# ### Requirements
#
# - Pyhton 3.10 or higher (up to 3.11) is highly recommended,
# - a user license for ecoinvent v.3,
# - the energy contribution rte based on ecoinvent excel file,
# - the electrolyzers LCI excel file

# %% [markdown]
# ### Import the required libraries:

# %%
import brightway2 as bw
import bw2io as bi

# %% [markdown]
# ### Create your Brightway2 project:

# %%
bw.projects.set_current("name_your_project")

# %% [markdown]
# ### Load the biosphere on it:

# %%
bw.bw2setup()
# Out:
# Biosphere database already present!!! No setup is needed

# %% [markdown]
# ### Load the Ecoinvent 3.9.1 database on it:

# %%
fp = r'path_to_your_ecoinvent_database_file'
ei39imp = bw.SingleOutputEcospold2Importer(fp, 'ei_3.9.1') # (fp, 'name_your_database')
ei39imp.apply_strategies()
ei39imp.statistics()
if not list(ei39imp.unlinked):  # Empty list evaluates to False, if all your exchanges are linked this equals to False
    ei39imp.write_database()
# Out:
# Extracting ecospold2 files:
#
# Total time elapsed: 00:05:59
# ####] 100% | ETA: 00:00:00 | Item ID: fffede58-fed2-5
# Title: Extracting ecospold2 files:
#   Started: 02/17/2025 17:36:33
#   Finished: 02/17/2025 17:42:32
#   Total time elapsed: 00:05:59
#   CPU %: 44.70
#   Memory %: 9.01
# Extracted 21238 datasets in 363.26 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: update_social_flows_in_older_consequential
# Applying strategy: set_lognormal_loc_value
# Applied 22 strategies in 14.83 seconds
# 21238 datasets
# 674593 exchanges
# 0 unlinked exchanges
# Writing activities to SQLite3 database:
#
# Total time elapsed: 00:01:04
# ####] 100% | ETA: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/17/2025 17:42:48
#   Finished: 02/17/2025 17:43:53
#   Total time elapsed: 00:01:04
#   CPU %: 58.10
#   Memory %: 9.42
# Created database: ei_3.9.1

# %% [markdown]
# ### Alternatively, you can load Ecoinvent directly from Ecoquery:

# %%
#bi.import_ecoinvent_release(
#        version='3.9.1',
#        system_model='cutoff', # can be cutoff / apos / consequential / EN15804
#        username='your_username',
#        password='your_password'
#    )

# %% [markdown]
# ### Check if you have biosphere3 and ei_3.9.1 listed on your project:

# %%
bw.databases
# Out:
# Databases dictionary with 2 object(s):
# 	biosphere3
# 	ei_3.9.1

# %% [markdown]
# ### Import the excel database for the foreground system:
# This database contains the LCI for the stacks, balance of plant and treatment for PEM and Alcaline electrolyzers.
# It also contain the inventory for tanks and ammonia system (not implemented yet)

# %%
imp = bw.ExcelImporter(r"electrolyzers_LCI.xlsx") 
imp.apply_strategies()
imp.match_database("ei_3.9.1", fields=('name', 'reference product', 'unit', 'location')) 
imp.match_database("biosphere3", fields=('name', 'unit', 'categories')) 
imp.match_database(fields=['name'])

#to verify what was don
imp.statistics()
#if unlinked flows exist
imp.write_excel(only_unlinked=True)
imp.write_database()
# Out:
# Extracted 1 worksheets in 0.18 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 10.44 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Writing activities to SQLite3 database:
# Applying strategy: link_iterable_by_fields
# 15 datasets
# 324 exchanges
# 0 unlinked exchanges
#
# Wrote matching file to:
# C:\Users\jsteinbach\AppData\Local\pylca\Brightway3\name_your_project.caab4f9ea87e60248946619d9504502b\output\db-matching-AECPEM-unlinked.xlsx
# Total time elapsed: 00:00:00
# A: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/17/2025 17:58:52
#   Finished: 02/17/2025 17:58:52
#   Total time elapsed: 00:00:00
#   CPU %: 34.00
#   Memory %: 10.18
# Created database: AEC/PEM

# %% [markdown]
# ### Import the excel database where RTE was modelled with neighboring market group (without the use of IAMs):

# %%
imp = bw.ExcelImporter(r"energy contribution rte based on ecoinvent.xlsx") 
imp.apply_strategies()
imp.match_database("ei_3.9.1", fields=('name', 'reference product', 'unit', 'location')) 
imp.match_database("biosphere3", fields=('name', 'unit', 'categories')) 
imp.match_database(fields=['name'])

#to verify what was don
imp.statistics()
#if unlinked flows exist
imp.write_excel(only_unlinked=True)
imp.write_database()
# Out:
# Extracted 1 worksheets in 0.11 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# Applying strategy: assign_only_product_as_production
# Applying strategy: link_technosphere_by_activity_hash
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applying strategy: convert_activity_parameters_to_list
# Applied 16 strategies in 10.24 seconds
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# Applying strategy: link_iterable_by_fields
# 3 datasets
# 80 exchanges
# 0 unlinked exchanges
#
# Wrote matching file to:
# C:\Users\jsteinbach\AppData\Local\pylca\Brightway3\name_your_project.caab4f9ea87e60248946619d9504502b\output\db-matching-RTE-scenarios-N_I-unlinked.xlsx
# Writing activities to SQLite3 database:
#
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 02/17/2025 17:59:10
#   Finished: 02/17/2025 17:59:10
#   Total time elapsed: 00:00:00
#   CPU %: 0.00
#   Memory %: 10.17
# Created database: RTE scenarios N_I

# %% [markdown]
# ### The RTE databases modelled with neighboring market group was created to model RTE scenarios under several assumptions including:
# - No efficiencies improvements were applied to the technologies;
# - Flexibilities were modeled as a single activity, with its share scaled to 1.5 times that of the French electricity market activity;
# - Switzerland market for electricity activity was not altered for 2050;
# - Belgium modelling was simplified by redistributing proportinally the shares of fossil fuels into the low carbon alternatives;
# - It is currently not possible to match this database with one where IAMs have been applied as the electricity updates applied by Premise dissolve national markets making it not suitable for a system where the neighbouring countries are modelled individually;
# - When this database is used in the web app, one should keep in mind that the PV activity available in Ecoinvent, without any modifications, does not reflect current PV efficiencies, let alone the efficiencies expected in 2050.

# %%
imp = bw.ExcelImporter(r"lci-PV.xlsx") 
imp.apply_strategies()
imp.match_database("ei_3.9.1", fields=('name', 'reference product', 'unit', 'location')) 
imp.match_database("biosphere3", fields=('name', 'unit', 'categories')) 
imp.match_database(fields=['name'])

#to verify what was don
imp.statistics()
#if unlinked flows exist
imp.write_excel(only_unlinked=True)
imp.write_database()
# Out:
# Extracted 1 worksheets in 1.59 seconds
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_restore_booleans
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: csv_add_missing_exchanges_section
# Applying strategy: normalize_units
# Applying strategy: normalize_biosphere_categories
# Applying strategy: normalize_biosphere_names
# Applying strategy: strip_biosphere_exc_locations
# Applying strategy: set_code_by_activity_hash
# Applying strategy: link_iterable_by_fields
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 imp = bw.ExcelImporter(r"lci-PV.xlsx")
# ----> 2 imp.apply_strategies()
#       3 imp.match_database("ei_3.9.1", fields=('name', 'reference product', 'unit', 'location'))
#       4 imp.match_database("biosphere3", fields=('name', 'unit', 'categories'))
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2io\importers\base.py:69, in ImportBase.apply_strategies(self, strategies, verbose)
#      67 total = len(func_list)
#      68 for i, func in enumerate(func_list):
# ---> 69     self.apply_strategy(func, verbose)
#      70     if hasattr(self, "signal") and hasattr(self.signal, "emit"):
#      71         self.signal.emit(i + 1, total)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2io\importers\base.py:48, in ImportBase.apply_strategy(self, strategy, verbose)
#      46     print("Applying strategy: {}".format(func_name))
#      47 try:
# ---> 48     self.data = strategy(self.data)
#      49     self.applied_strategies.append(func_name)
#      50 except StrategyError as err:
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2io\utils.py:182, in ExchangeLinker.link_iterable_by_fields(cls, unlinked, other, fields, kind, internal, relink)
#     180 try:
#     181     for ds in other:
# --> 182         key = cls.activity_hash(ds, fields)
#     183         if key in candidates:
#     184             duplicates.setdefault(key, []).append(ds)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2io\utils.py:149, in ExchangeLinker.activity_hash(cls, act, fields, case_insensitive, strip)
#     117 @classmethod
#     118 def activity_hash(
#     119         cls, act, fields=DEFAULT_FIELDS, case_insensitive=True, strip=True
#     120 ):
#     121     """Hash an activity dataset.
#     122
#     123     Used to import data formats like ecospold 1 (ecoinvent v1-2) and SimaPro, where no unique attributes for\
#    (...)
#     146
#     147     """
#     148     string = "".join(
# --> 149         [
#     150             cls.parse_field(
#     151                 field_value=cls.field_funcs.get(field, cls.field_funcs["default"])(
#     152                     act, field
#     153                 ),
#     154                 case_insensitive=case_insensitive,
#     155                 strip=strip,
#     156             )
#     157             for field in fields or DEFAULT_FIELDS
#     158         ]
#     159     )
#     160     return str(hashlib.md5(string.encode("utf-8")).hexdigest())
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2io\utils.py:151, in <listcomp>(.0)
#     117 @classmethod
#     118 def activity_hash(
#     119         cls, act, fields=DEFAULT_FIELDS, case_insensitive=True, strip=True
#     120 ):
#     121     """Hash an activity dataset.
#     122
#     123     Used to import data formats like ecospold 1 (ecoinvent v1-2) and SimaPro, where no unique attributes for\
#    (...)
#     146
#     147     """
#     148     string = "".join(
#     149         [
#     150             cls.parse_field(
# --> 151                 field_value=cls.field_funcs.get(field, cls.field_funcs["default"])(
#     152                     act, field
#     153                 ),
#     154                 case_insensitive=case_insensitive,
#     155                 strip=strip,
#     156             )
#     157             for field in fields or DEFAULT_FIELDS
#     158         ]
#     159     )
#     160     return str(hashlib.md5(string.encode("utf-8")).hexdigest())
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2io\utils.py:86, in ExchangeLinker.<lambda>(act, field)
#      83 class ExchangeLinker:
#      84     re_sub = re.compile(r"[()\[\],'\"]")
# ---> 86     field_funcs = {"default": lambda act, field: act.get(field, "")}
#      88     @staticmethod
#      89     def parse_field(
#      90             field_value,
#    (...)
#      93             re_sub=re_sub,
#      94     ):
#      95         if field_value is None:
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\_collections_abc.py:774, in Mapping.get(self, key, default)
#     772 'D.get(k[,d]) -> D[k] if k in D, else d.  d defaults to None.'
#     773 try:
# --> 774     return self[key]
#     775 except KeyError:
#     776     return default
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2data\backends\peewee\proxies.py:121, in Activity.__getitem__(self, key)
#     118     return self._data[key]
#     120 try:
# --> 121     rp = self.rp_exchange()
#     122 except ValueError:
#     123     raise KeyError
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2data\backends\peewee\proxies.py:285, in Activity.rp_exchange(self)
#     278 def rp_exchange(self):
#     279     """Return an ``Exchange`` object corresponding to the reference production. Uses the following in order:
#     280
#     281     * The ``production`` exchange, if only one is present
#     282     * The ``production`` exchange with the same name as the activity ``reference product``.
#     283
#     284     Raises ``ValueError`` if no suitable exchange is found."""
# --> 285     candidates = list(self.production())
#     286     if len(candidates) == 1:
#     287         return candidates[0]
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\bw2data\backends\peewee\proxies.py:83, in Exchanges.__len__(self)
#      82 def __len__(self):
# ---> 83     return self._get_queryset().count()
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2036, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    2033 if not database:
#    2034     raise InterfaceError('Query must be bound to a database in order '
#    2035                          'to call "%s".' % method.__name__)
# -> 2036 return method(self, database, *args, **kwargs)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2321, in SelectBase.count(self, database, clear_limit)
#    2319 except AttributeError:
#    2320     pass
# -> 2321 return Select([clone], [fn.COUNT(SQL('1'))]).scalar(database)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2036, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    2033 if not database:
#    2034     raise InterfaceError('Query must be bound to a database in order '
#    2035                          'to call "%s".' % method.__name__)
# -> 2036 return method(self, database, *args, **kwargs)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2301, in SelectBase.scalar(self, database, as_tuple, as_dict)
#    2299 if as_dict:
#    2300     return self.dicts().peek(database)
# -> 2301 row = self.tuples().peek(database)
#    2302 return row[0] if row and not as_tuple else row
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2036, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    2033 if not database:
#    2034     raise InterfaceError('Query must be bound to a database in order '
#    2035                          'to call "%s".' % method.__name__)
# -> 2036 return method(self, database, *args, **kwargs)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2286, in SelectBase.peek(self, database, n)
#    2284 @database_required
#    2285 def peek(self, database, n=1):
# -> 2286     rows = self.execute(database)[:n]
#    2287     if rows:
#    2288         return rows[0] if n == 1 else rows
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2036, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    2033 if not database:
#    2034     raise InterfaceError('Query must be bound to a database in order '
#    2035                          'to call "%s".' % method.__name__)
# -> 2036 return method(self, database, *args, **kwargs)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2107, in BaseQuery.execute(self, database)
#    2105 @database_required
#    2106 def execute(self, database):
# -> 2107     return self._execute(database)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:2280, in SelectBase._execute(self, database)
#    2278 def _execute(self, database):
#    2279     if self._cursor_wrapper is None:
# -> 2280         cursor = database.execute(self)
#    2281         self._cursor_wrapper = self._get_cursor_wrapper(cursor)
#    2282     return self._cursor_wrapper
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:3330, in Database.execute(self, query, commit, **context_options)
#    3328 ctx = self.get_sql_context(**context_options)
#    3329 sql, params = ctx.sql(query).query()
# -> 3330 return self.execute_sql(sql, params)
#
# File C:\local\jsteinbach\Anaconda_3\envs\agb\Lib\site-packages\peewee.py:3322, in Database.execute_sql(self, sql, params, commit)
#    3320 with __exception_wrapper__:
#    3321     cursor = self.cursor()
# -> 3322     cursor.execute(sql, params or ())
#    3323 return cursor
#
# KeyboardInterrupt:
